# %%
import math
import requests
from bs4 import BeautifulSoup
import json
import time
import random
import numpy as np
# from discord_webhook import DiscordWebhook

# %load_ext autoreload
# %autoreload 2

from main import *

# %%
page = requests.get("https://www.alza.cz/amd-ryzen-7-7800x3d-d7665224.htm?o=1", cookies=AzlaCookies, headers=AzlaHeaders)
with open('alza.html', 'wb+') as f:
    f.write(page.content)
soup = BeautifulSoup(page.content, "html.parser")
results = soup.find("ul", {"class": "fmenu"})
subs = results.find_all("a", {"class": "catLink"})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 6
#       4 soup = BeautifulSoup(page.content, "html.parser")
#       5 results = soup.find("ul", {"class": "fmenu"})
# ----> 6 subs = results.find_all("a", {"class": "catLink"})
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
import requests


cookies = {
    'VZTX': '8425162884',
    'VST': '149e623e-678d-ee11-843c-0c42a19546e5',
    '__cf_bm': 'iWlqoFJKhrAtfq0SWzVLGOyDN7A7vxHIwNtNLkOrQI4-1707952444-1.0-ARzlD8f7lFCakOtgNhaB6hDTuoQYnd20L/nHxwJdJz5vRNAjo5jxF9RUbae0OhKx1svK9gBEzaeABhKeE+H6sOI=',
    'lb_id': '85d064962b8cd1f2bae5373d9aa21ec4',
    'CriticalCSSMobileDefault': '12837855',
    'CriticalCSSMobileUnknown': '12837855',
    'CriticalCSSMobileDetail': '12837855',
}

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:122.0) Gecko/20100101 Firefox/122.0',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
    'Accept-Language': 'cs,sk;q=0.8,en-US;q=0.5,en;q=0.3',
    'DNT': '1',
    'Sec-GPC': '1',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'none',
    'Sec-Fetch-User': '?1',
}

data = '{idCategory:18842899,producers:,parameters:^[^],idPrefix:0,prefixType:0,page:1,pageTo:2,availabilityType:0,newsOnly:false,commodityStatusType:null,upperDescriptionStatus:0,branchId:-2,sort:0,categoryType:1,searchTerm:,layout:1,append:true,yearFrom:null,yearTo:null,artistId:null,minPrice:-1,maxPrice:-1,showOnlyActionCommodities:false,callFromParametrizationDialog:false,commodityWearType:null,configurationId:3,scroll:4896,hash:^#f&cst=null&cud=0&pg=1-2&prod=,counter:1}'

response = requests.post('https://www.alza.cz/amd-ryzen-7-7800x3d-d7665224.htm', cookies=cookies, headers=headers)
with open('alza.html', 'wb+') as f:
    f.write(response.content)
response = requests.post('https://m.alza.cz/amd-ryzen-7-7800x3d-d7665224.htm', cookies=cookies, headers=headers)
with open('alza-mobil.html', 'wb+') as f:
    f.write(response.content)

# %%
original_value = 'iWlqoFJKhrAtfq0SWzVLGOyDN7A7vxHIwNtNLkOrQI4-1707952444-1.0-ARzlD8f7lFCakOtgNhaB6hDTuoQYnd20L/nHxwJdJz5vRNAjo5jxF9RUbae0OhKx1svK9gBEzaeABhKeE+H6sOI='
value2 = 'Jqr5BVQQW6Q1w1MYhYtfDnpg4lLaB7.nsIBPajr3c30-1707952908-1.0-Ac4ReYPcmGhddeTATqqumQ++BBrqgyNrgtQjrtDKDFBodJOoT79xNCrx7LXOhQ8eNMykI8Yu/0xdVhnO5GIc0JQ='
value3 = 'Y447uInxM7hEDYsS_DF4ANPHML9nmX10PqevLVbMQRw-1707953614-1.0-AZk8ZNI+FNRmqkEU3UAvJ1fPI4qOjIva+k5ainMgVsAqRDceWQbO1YLD0lP47Nhmk4CjkZkCzzb82gtJHAh8r+s='

builder = ''
for chars in zip(original_value, value2, value3):
	if len(set(chars)) == 1:
		builder += chars[0]
	else:
		builder += random.choice(chars)
		
print(original_value)
print(value2)
print(value3)
print(builder)
# Out:
# iWlqoFJKhrAtfq0SWzVLGOyDN7A7vxHIwNtNLkOrQI4-1707952444-1.0-ARzlD8f7lFCakOtgNhaB6hDTuoQYnd20L/nHxwJdJz5vRNAjo5jxF9RUbae0OhKx1svK9gBEzaeABhKeE+H6sOI=
# Jqr5BVQQW6Q1w1MYhYtfDnpg4lLaB7.nsIBPajr3c30-1707952908-1.0-Ac4ReYPcmGhddeTATqqumQ++BBrqgyNrgtQjrtDKDFBodJOoT79xNCrx7LXOhQ8eNMykI8Yu/0xdVhnO5GIc0JQ=
# Y447uInxM7hEDYsS_DF4ANPHML9nmX10PqevLVbMQRw-1707953614-1.0-AZk8ZNI+FNRmqkEU3UAvJ1fPI4qOjIva+k5ainMgVsAqRDceWQbO1YLD0lP47Nhmk4CjkZkCzzb82gtJHAh8r+s=
# J445BFJKM6A1D10SWDF4ANPD4797B7.0PIBNLVO3Q30-1707952404-1.0-AR48D8I+FFCadOEA3UAB61++B4QOgI20+/5HinDKDF5oRDAeT59O19LD0LP07N8e14CK98BC/0b82gKJ5+H60+I=

# %%
import uuid
import random
import string

original_value = 'iWlqoFJKhrAtfq0SWzVLGOyDN7A7vxHIwNtNLkOrQI4-1707952444-1.0-ARzlD8f7lFCakOtgNhaB6hDTuoQYnd20L/nHxwJdJz5vRNAjo5jxF9RUbae0OhKx1svK9gBEzaeABhKeE+H6sOI='
random_string = builder


cookies = {
    'VZTX': str(random.randint(1000000000, 9999999999)),
    'VST': str(uuid.uuid4()),
    '__cf_bm': random_string,
    'lb_id': str(uuid.uuid4()),
    'CriticalCSSMobileDefault': str(random.randint(10000000, 99999999)),
    'CriticalCSSMobileUnknown': str(random.randint(10000000, 99999999)),
    'CriticalCSSMobileDetail': str(random.randint(10000000, 99999999)),
}

print(cookies)

response = requests.post('https://www.alza.cz/amd-ryzen-7-7800x3d-d7665224.htm', cookies=cookies, headers=headers)
with open('alza.html', 'wb+') as f:
    f.write(response.content)
response = requests.post('https://m.alza.cz/amd-ryzen-7-7800x3d-d7665224.htm', cookies=cookies, headers=headers)
with open('alza-mobil.html', 'wb+') as f:
    f.write(response.content)
# Out:
# {'VZTX': '1549651989', 'VST': '5a27bca1-7e90-4119-aee4-cab485b8e38e', '__cf_bm': 'J445BFJKM6A1D10SWDF4ANPD4797B7.0PIBNLVO3Q30-1707952404-1.0-AR48D8I+FFCadOEA3UAB61++B4QOgI20+/5HinDKDF5oRDAeT59O19LD0LP07N8e14CK98BC/0b82gKJ5+H60+I=', 'lb_id': '186c5a2c-77e8-4389-886b-8c5180ac161b', 'CriticalCSSMobileDefault': '85663092', 'CriticalCSSMobileUnknown': '46350206', 'CriticalCSSMobileDetail': '69528921'}

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8" />
# <title>Alza.cz</title>
# <meta name="viewport" content="width=device-width, initial-scale=1" />
# <link rel="shortcut icon" href="/favicon-alza.ico" type="image/x-icon" />
# ...

# %%
processCzc('https://www.czc.cz/servery-servery-a-datova-uloziste/produkty?q-first=0&dostupnost=skladem&stav-zbozi=nove&stitky=garance-skvele-ceny')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 processCzc('https://www.czc.cz/servery-servery-a-datova-uloziste/produkty?q-first=0&dostupnost=skladem&stav-zbozi=nove&stitky=garance-skvele-ceny')
#
# File ~\OneDrive - České vysoké učení technické v Praze\Dokumenty\PycharmProjects\CZC scam bot\main.py:157, in processCzc(URL)
#     155     remove += "\nczc- {} {}".format(URL[-63], URL)
#     156     return
# --> 157 articles = results.find_all("div", class_="new-tile")
#     159 for article in articles:
#     160     temp = json.loads(article.attrs["data-ga-impression"])
#
# File _pydevd_bundle\pydevd_cython_win32_310_64.pyx:1179, in _pydevd_bundle.pydevd_cython_win32_310_64.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\pydevd_cython_win32_310_64.pyx:620, in _pydevd_bundle.pydevd_cython_win32_310_64.PyDBFrame.trace_dispatch()
#
# ...

# %%
import winsound
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)

# %%
import requests

page = requests.get("https://www.alza.cz", headers=AzlaHeaders)
soup = BeautifulSoup(page.content, "html.parser")
results = soup.find("ul", {"class": "fmenu"})
subs = results.find_all("a", {"class": "catLink"})
interesting = ['/mobily/18843445.htm', '/notebooky/18842920.htm', '/pocitace/18852653.htm', '/komponenty/18852654.htm', '/lcd-monitory/18842948.htm', '/prislusenstvi/18861668.htm', '/sitove-prvky/18842916.htm', '/tiskarny-a-skenery/18851089.htm', '/televize/18849604.htm', '/sluchatka/18843602.htm', '/priprava-jidla/18879690.htm', '/vysavace/18850975.htm', '/spotrebice-na-pripravu-napoju/18850364.htm', '/kuchynske-potreby/18858834.htm', '/hobby/nabytek/18871096.htm', '/elektroinstalace/18875780.htm', '/smarthome-inteligentni-domacnost/18855843.htm', '/hobby/naradi/18858962.htm', '/hobby/vybaveni-dilny/18862227.htm', '/alkohol/18872276.htm', '/nealkoholicke-napoje/18881193.htm', '/sladkosti/18876397.htm', '/trvanlive-potraviny/18876335.htm', '/smarthealth-chytre-zdravi/18855195.htm', '/pristroje-pro-peci-o-zdravi/18850366.htm', ]
list = set()
for t in subs:
	if t.attrs['href'] in interesting:
		print([t.attrs['href'] for t in [r for r in t.next_siblings][1].find_all("a", {"class": "subCat"})])
		list.update([t.attrs['href'] for t in [r for r in t.next_siblings][1].find_all("a", {"class": "subCat"})])
	# else:
	# 	lis.add(t.attrs['href'])
len(list)
# Out:
# ['/vykup-mobilu/18894351.htm', '/chytre-telefony/18845588.htm', '/tlacitkove-telefony/18844044.htm', '/iphone/18851638.htm', '/mobily-samsung/18855066.htm', '/mobilni-telefony-xiaomi/18863045.htm', '/mobilni-telefony-realme/18875706.htm', '/mobilni-telefony-oneplus/18871324.htm', '/mobilni-telefony-motorola/18862488.htm', '/mobilni-telefony-dle-ceny/18865103.htm', '/mobily/produkty-k-pronajmu/18843445-e15.htm', '/stolni-telefony/18865095.htm', '/prislusenstvi-pro-mobilni-telefony/18844551.htm']
# ...

# %%
page = requests.get("https://www.alza.cz/nejprodavanejsi-nejlepsi-monitory-pro-praci-z-domova/18876116.htm#f&availabilityFilterValue=1&cst=1&cud=0&pg=1&pn=7&prod=", headers=AzlaHeaders)
soup = BeautifulSoup(page.content, "html.parser")
results = soup.find("div", id="boxes")
tmp = None
for child in results.children:
	if child != '\n':
		article = child.find("a")
		if article:
			price = float(article.attrs["data-impression-metric2"].replace(',', '.'))
			name = article.attrs["data-impression-name"]
			supply = article.attrs["data-impression-dimension13"]
			link = 'https://www.alza.cz/' + article.attrs["href"]
			print(price, name, supply, link)
		# break
# Out:
# 7499.0 Intel Core i7-10700KF Skladem > 5 ks https://www.alza.cz//intel-core-i7-10700kf-d5813507.htm
# 19990.0 AMD Ryzen 9 7950X Skladem > 5 ks https://www.alza.cz//amd-ryzen-9-7950x-d7435937.htm
# 32390.0 Intel Core i9-10980XE Skladem 4 ks u partnera https://www.alza.cz//gaming/intel-core-i9-10980xe-d5708794.htm
# 4690.0 AMD Ryzen 5 5600X Skladem > 5 ks https://www.alza.cz//amd-ryzen-5-5600x-d6205102.htm
# 3790.0 AMD Ryzen 5 5600 Skladem > 5 ks https://www.alza.cz//amd-ryzen-5-5600-d7082021.htm
# 6790.0 AMD Ryzen 7 5800X Skladem > 5 ks https://www.alza.cz//amd-ryzen-7-5800x-d6205103.htm
# 9890.0 AMD Ryzen 9 5900X Skladem > 5 ks https://www.alza.cz//amd-ryzen-9-5900x-d6215746.htm
# 5399.0 Intel Core i5-12400F Skladem > 5 ks https://www.alza.cz//intel-core-i5-12400f-d6939807.htm
# 5749.0 Intel Core i5-11400 Skladem > 5 ks https://www.alza.cz//intel-core-i5-11400-d6329357.htm
# 3590.0 AMD Ryzen 5 5600G Skladem > 5 ks https://www.alza.cz//amd-ryzen-5-5600g-d6667494.htm
# ...

# %%
temp = [t.attrs['href'] for t in [t for t in subs[38].next_siblings][1].find_all("a", {"class": "subCat"})]
temp
# Out:
# ['/gaming/herni-konzole-nintendo-switch/18861898.htm',
#  '/gaming/hry-pro-nintendo-switch/18860898.htm',
#  '/gaming/prislusenstvi-pro-nintendo-switch/18860897.htm',
#  '/gaming/nintendo-switch-online/18876358.htm',
#  '/gaming/nintendo-store/18879052.htm',
#  '/gaming/nintendo-switch/bazar-pouzite-zbozi/u18860896.htm']

# %%
with open("azla.json", "r") as read_file:
    a1 = json.load(read_file)
with open("azla2.json", "r") as read_file:
    a2 = json.load(read_file)
for k in a1:
	print(k, a1[k], a2[k])
# Out:
# Realme 8 DualSIM 4GB/64GB černá 4789.0 4789.0
# iPhone 11 128GB černá 13990.0 13690.0
# Samsung Galaxy S22 5G 256GB černá 22990.0 20990.0
# Asus Zenfone 8 8GB/128GB černá 13490.0 10890.0
# iPhone 11 64GB černá 12990.0 12190.0
# iPhone 12 128GB černá 21490.0 19790.0
# Samsung Galaxy A52s 5G černá 11490.0 9499.0
# Asus Zenfone 8 8GB/128GB stříbrná 13490.0 13490.0
# Samsung Galaxy A53 5G 128GB černá 9989.0 9779.0
# iPhone 12 128GB bílá 19990.0 19990.0
# Samsung Galaxy A33 5G černá 7999.0 7999.0
# Samsung Galaxy Z Fold4 12GB/512GB černá 47990.0 44890.0
# iPhone 11 128GB bílá 14690.0 14690.0
# iPhone SE 64GB černá 2022 12490.0 12490.0
# iPhone 13 mini 256GB černá 22990.0 22990.0
# iPhone 12 64GB černá 19990.0 16990.0
# iPhone 12 Mini 64GB černá 16990.0 16990.0
# iPhone 13 mini 128GB černá 18990.0 18990.0
# iPhone 13 Pro 128GB zlatá 29490.0 29490.0
# Samsung Galaxy Z Flip4 8GB/256GB šedá 28999.0 28999.0
# iPhone 11 64GB bílá 12990.0 12490.0
# ...

# %%
def generateMountUrls(names):
	pass


def getMountCategories():
	ret = []
	blacklist = ['https://bazeny.mountfield.cz/']
	page = requests.get("https://www.mountfield.cz/")
	soup = BeautifulSoup(page.content, "html.parser")
	bar = soup.find_all("div", {"class": "list-submenu__image"})
	for result in bar:
		if result != '\n':
			# print(result.contents[1].attrs['href'])
			category = result.contents[1].attrs['href']
			if category not in blacklist:
				ret.append(category)
	return [*set(ret)]

def processMount(URL):
	for i in range(3):
		try:
			page = requests.get(URL)
			break
		except Exception as e:
			print(e)
			if i == 2:
				log = DiscordWebhook(
					url=logWebHookUrl,
					content="<@313378412494585856>\nError in Mount: {}\n{}".format(e, URL))
				hook = log.execute()
				return
			log = DiscordWebhook(
				url=logWebHookUrl,
				content="Error in Mount: {}\n{}".format(e, URL))
			hook = log.execute()
			time.sleep(6 + random.random() * 3)
	soup = BeautifulSoup(page.content, "html.parser")
	results = soup.find("div", {"class": "list-products__in"}).contents[1].contents
	# if results is None:
	# 	# log = DiscordWebhook(
	# 	#     url=logWebHookUrl,)
	# 	# content="<@313378412494585856>\nNo results for: {}".format(URL))
	# 	# hook = log.execute()
	# 	print("Mount- {}".format(URL))
	# 	return
	# articles = results.find_all("div", class_="new-tile")
	#
	for article in results:
		if article != '\n':
			temp = article.contents[1].contents[3].attrs
			link = temp['href']
			data = json.loads(temp['data-gtm'])['ecommerce']['click']['products'][0]
			price = data['priceWithTax']
			name = data['name']
			id = data['id']
			supply = data['availability']
			print(name, price, supply, link)
			if oldPrice := dbMount.get(id) is not None:
				checkPrice(name, price, oldPrice, supply, link)
			dbMount[id] = price

# %%
# dbMount = {}
kms = getMountCategories()
# for page in kms[18:]:
# 	processMount(page)

# %%
processMount(kms[80])

# %%
test = ['/xiaomi-mobilni-telefony/produkty', '/dychaci-trenazery-zdravi/produkty',
                 '/virtualni-realita/produkty', '/glukometry-zdravi/produkty', '/metalearth-iconx-stavebnice/produkty',
                 '/xbox-series-gaming/produkty', '/tlakomery-zdravi/produkty',
                 '/stolni-hry-stolni-a-venkovni-hry/produkty', '/sport/produkty',
                 '/hrani-her-nejoblibenejsi-zajmy/produkty', '/mobilni-telefony-honor/produkty',
                 '/rozvadece-servery/produkty', '/piatnik-spolecenske-hry/produkty',
                 '/hlasovy-asistent-smart-domacnost/produkty', '/graficke-karty/produkty',
                 '/osobni-vahy-zdravi/produkty', '/polstare-zdravi/produkty',
                 '/relaxacni-sluchatka-chytra-domacnost/produkty', '/susene-maso/produkty',
                 '/vedomostni-hry-zabava/produkty', '/vlasova-kosmetika/produkty',
                 '/grizly-mixit-a-zdrava-vyziva/produkty', '/elektronicka-evidence-trzeb/produkty',
                 '/knizni-serie-knihy/produkty', '/kalhoty-fashion/produkty', '/kulickove-drahy/produkty',
                 '/svicky-relaxace-a-difuzery/produkty', '/oxymetry-zdravi/produkty', '/hry-pro-pc-gaming/produkty',
                 '/mindok-spolecenske-hry/produkty', '/konfigurovatelne-nas-nas-servery/produkty',
                 '/parfemy-drogerie/produkty', '/ergonomie/produkty', '/nas-servery/produkty',
                 '/adc-blackfire-spolecenske-hry/produkty', '/rohozky-geekultura/produkty', '/slane-snacky/produkty',
                 '/18plus-lab/produkty', '/venkovni-hry-zabava/produkty', '/pece-o-plet-drogerie/produkty',
                 '/fitness-naramky/produkty', '/realme-mobilni-telefony/produkty',
                 '/tp-link-omada-cloudove-reseni/produkty', '/monitory-spanku-zdravi/produkty',
                 '/ctecky-e-knih-a-digitalni-zapisniky/produkty', '/herni-konzole-gaming/produkty',
                 '/se-zdravotnymi-funkcemi-chytre-hodinky/produkty', '/hubelino-zabava/produkty',
                 '/robotime-zabava/produkty', '/masazni-pistole-zdravi/produkty', '/mobilni-telefony-samsung/produkty',
                 '/akcni-nabidky-chutovky/produkty', '/skolni-pomucky-pro-male-hrace/produkty',
                 '/knihy-pro-osobni-rozvoj-knihy/produkty', '/svetelne-terapeuticke-lampy-zdravi/produkty',
                 '/princezny-nejoblibenejsi-zajmy/produkty', '/lego-pro-dospele/produkty', '/procesory/produkty',
                 '/geek-prislusenstvi-geekultura/produkty', '/svetla-a-lampicky/produkty',
                 '/penezenky-fashion/produkty', '/telekomunikace-a-kamery/produkty', '/small-foot-zabava/produkty',
                 '/pedro/produkty', '/servery-servery-a-datova-uloziste/produkty',
                 '/sportovni-sluchatka-a-mikrofony/produkty', '/mikiny-a-svetry-fashion/produkty',
                 '/komiksy-pro-deti/produkty', '/zviratka-nejoblibenejsi-zajmy/produkty', '/oshee-napoje/produkty',
                 '/opticke-site/produkty', '/party-hry-zabava/produkty', '/smart-zubni-hygiena/produkty',
                 '/gps-navigace/produkty', '/darkove-sady-drogerie/produkty', '/herni-tematika-komiksy/produkty',
                 '/rexhry-spolecenske-hry/produkty', '/iron-studios-figurky/produkty', '/samsung-komponenty/produkty',
                 '/geek-tipy/produkty', '/iphone-mobilni-telefony/produkty', '/albi-spolecenske-hry/produkty',
                 '/mechaniky/produkty', '/software-microsoft/produkty', '/playstation-5-gaming/produkty',
                 '/videokamery/produkty', '/marvel-komiksy/produkty', '/domaci-testy-zdravi/produkty',
                 '/lahve-hrnky-termosky-zdravi/produkty', '/skladove-systemy/produkty',
                 '/super-hrdinove-nejoblibenejsi-zajmy/produkty', '/modni-doplnky-fashion/produkty',
                 '/vysavace-smart-zarizeni/produkty', '/puzzle-zabava/produkty', '/sportovni-chytre-hodinky/produkty',
                 '/dc-komiksy/produkty', '/zdrave-mlsani/produkty', '/software/produkty',
                 '/kancelarska-technika/produkty', '/intel-komponenty/produkty', '/hracky-zabava/produkty',
                 '/fotovoltaika/produkty', '/energeticke-napoje/produkty', '/bundy-fashion/produkty',
                 '/komiksove-serie/produkty', '/video/produkty', '/elektrostimulatory-zdravi/produkty', '/bombus/produkty', '/space-protein/produkty', '/zdrave-napoje/produkty', '/kase-a-musli-zdrava-vyziva-a-doplnky-stravy/produkty', '/dychaci-trenazery-zdravi/produkty', '', '/dezinfekcni-gely/produkty', '/odvlhcovace-velke-spotrebice/produkty', '/tycinky-mixit-a-zdrava-vyziva/produkty', '/respiratory-a-rousky/produkty', '/teplomery/produkty', '/cisticky-vzduchu-smart-spotrebice/produkty', '/uv-lampy-zdravi/produkty', '/sezeni-u-pocitace-zdrava-kancelar/produkty', '/doplnky-stravy/produkty', '/zvlhcovac-vzduchu-smart-spotrebice/produkty', '/realme-mobilni-telefony/produkty']
print(len(test))
res = [*set(test)]
remove = ['/kompresorova-technika.html', '/sponkovacky.html', '/wi-fi-routery-a-komponenty-38598.html', '/merici-technika.html', '/herni-pocitace-39198.html', '/herni-monitory-39200.html', '/susicky-38648.html', '/herni-volanty-40160.html', '/prislusenstvi-k-videokameram-41727.html', '/krovinorezy.html', '/pily-37460.html', '/sekacky-na-travu.html', '/vysokotlake-cistice-37459.html', '/ostatni-prislusenstvi-39794.html', '/vrtacky.html', '/horni-frezky.html', '/herni-sluchatka-40159.html', '/pily.html', '/elektricka-zarizeni.html', '/pece-o-travnik-a-pudu.html', '/sroubovaky.html']
# print(res)
print(len(test), len(res))
# for i in remove:
# 	res.remove(i)
print(len(test), len(res))
print(res)
# Out:
# 124
# 124 122
# 124 122
# ...

# %%
print(getCzcCategories()[10])
print(getCzcCategories()[10])
print(getCzcCategories()[10])
print(getCzcCategories()[10])
print(getCzcCategories()[10])
# Out:
# https://www.czc.cz/mobilni-telefony/produkty?q-first=27&dostupnost=skladem&stav-zbozi=nove
# https://www.czc.cz/mobilni-telefony/produkty?q-first=27&dostupnost=skladem&stav-zbozi=nove
# https://www.czc.cz/mobilni-telefony/produkty?q-first=27&dostupnost=skladem&stav-zbozi=nove
# https://www.czc.cz/mobilni-telefony/produkty?q-first=27&dostupnost=skladem&stav-zbozi=nove
# https://www.czc.cz/mobilni-telefony/produkty?q-first=27&dostupnost=skladem&stav-zbozi=nove

# %%
blacklist =         ['/pece-o-ruce-a-nohy.html', '/notebooky-a-pc.html', '/chytra-domacnost.html', '/gamepady-pro-mobilni-telefony.html', '/kuchynske-vahy-krajece-a-mlynky.html', '/dtest-male-spotrebice.html', '/prislusenstvi-k-mobilnim-telefonum.html', '/meteostanice-digitalni-teplomery-hodiny-a-cas.html', '/vytapeni-a-chlazeni-domacnosti.html', '/baterie-a-nabijeni.html', '/gamepady-pro-konzole-a-pc.html', '/nintendo-konzole.html', '/virtualni-
atory-samostatne.html', '/brasny-a-pouzdra-pro-fotoaparaty.html', '/pametove-karty.html', '/stativy-pro-foto-a-video.html', '/ctecky-pametovych-karet.html', '/polarizacni-filtry.html', '/prislusenstvi-fotoaparaty-objektivy.html', '/prislusenstvi-fotoaparaty-blesky.html', '/prislusenstvi-fotoaparaty-ostatni.html', '/prislusenstvi-pro-instantni-fotoaparaty-a-fototiskarny.html', '/wifi-routery.html', '/adsl-vdsl-modemy.html', '/lte-modemy.html', '/wifi-extender.html', '/usb-sitove-adaptery.html', '/ip-kamery.html', '/powerline.html', '/switche.html', '/pristupovy-bod-ap.html', '/sitova-karta.html', '/zarovky-40113.html', '/lampicky.html', '/led-pasky.html', '/lampicky-a-svitilny.html', '/ostatni-osvetleni/1.html', '/philips-hue-41297.html', '/vanocni-osvetleni.html', '/chytre-osvetleni.html', '/zarovky-40113.html', '/lampicky.html', '/led-pasky.html', '/lampicky-a-svitilny.html', '/ostatni-osvetleni/1.html', '/philips-hue-41297.html', '/vanocni-osvetleni.html', '/chytre-osvetleni.html', '/zarovky-40113.html', '/lampicky.html', '/led-pasky.html', '/lampicky-a-svitilny.html', '/ostatni-osvetleni/1.html', '/philips-hue-41297.html', '/vanocni-osvetleni.html', '/chytre-osvetleni.html', '/filtry-tukove.html', '/filtry-uhlikove.html', '/potrubi.html', '/ostatni-prislusenstvi-39440.html', '/filtry-tukove.html', '/filtry-uhlikove.html', '/potrubi.html', '/ostatni-prislusenstvi-39440.html', '/filtry-tukove.html', '/filtry-uhlikove.html', '/potrubi.html', '/ostatni-prislusenstvi-39440.html', '/roboticke-sekacky.html', '/akumulatorove-sekacky.html', '/elektricke-sekacky.html', '/motorove-sekacky.html', '/strunove-sekacky.html', '/vretenove-sekacky.html', '/roboticke-sekacky.html', '/akumulatorove-sekacky.html', '/elektricke-sekacky.html', '/motorove-sekacky.html', '/strunove-sekacky.html', '/vretenove-sekacky.html', '/roboticke-sekacky.html', '/akumulatorove-sekacky.html', '/elektricke-sekacky.html', '/motorove-sekacky.html', '/strunove-sekacky.html', '/vretenove-sekacky.html', '/vysokotlake-cistice-37474.html', '/prislusenstvi-37475.html', '/vysokotlake-cistice-37474.html', '/prislusenstvi-37475.html', '/vysokotlake-cistice-37474.html', '/prislusenstvi-37475.html']
whitelist1 = whitelist
blacklist1 = blacklist
add = [*set(add)]
remove = [*set(remove)]
for r in remove:
	if r in add:
		add.remove(r)
		remove.remove(r)
		if r in whitelist:
			whitelist.remove(r)
for a in add:
	whitelist.append(a)
for r in remove:
	if r in whitelist:
		whitelist.remove(r)
	else:
		blacklist.append(r)
whitelist = [*set(whitelist)]
blacklist = [*set(blacklist)]

for b in blacklist:
	if b in whitelist:
		blacklist.remove(b)
		whitelist.remove(b)

for w in whitelist:
	if w[-10:-5].isnumeric():
		whitelist.remove(w)
		whitelist.append(w[:-11] + w[-5:])

print(len(whitelist), len(whitelist1))
print(len(blacklist), len(blacklist1))
print(whitelist)
print(blacklist)
# Out:
# 280 497
# 88 89
# ...
